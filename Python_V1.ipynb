# %% [markdown]
# ## Import Modules

# %%
import json
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
from tqdm import tqdm
from datetime import datetime

# %% [markdown]
# ## Define Function

# %%
def flatten(t):
    return [item for sublist in t for item in sublist]

# %% [markdown]
# ## Import Data

# %%
df_price = pd.read_excel("Price.xlsx", index_col=0) 
df_price.index = df_price.index.to_series().dt.to_period('M')
df_price
# Out:
#              Mnemonic  Close
# Date
# 2019-12  4SI:XJSE:EQU   32.0
# 2019-11  4SI:XJSE:EQU   20.0
# 2019-10  4SI:XJSE:EQU   20.0
# 2019-09  4SI:XJSE:EQU   20.0
# 2019-08  4SI:XJSE:EQU   18.0
# ...               ...    ...
# 2009-05  ZED:XJSE:EQU  144.0
# 2009-04  ZED:XJSE:EQU  148.0
# 2009-03  ZED:XJSE:EQU  140.0
# 2009-02  ZED:XJSE:EQU  146.0
# 2009-01  ZED:XJSE:EQU  155.0
#
# [42504 rows x 2 columns]

# %%
df_size = pd.read_excel("Market Capitalizations.xlsx", usecols=[0,2,3], index_col=1)
df_size.index = df_size.index.to_series().dt.to_period('M')
df_size
# Out:
#              Mnemonic   Market Cap
# Date
# 2019-12  4SI:XJSE:EQU  253217582.0
# 2019-11  4SI:XJSE:EQU  158260989.0
# 2019-10  4SI:XJSE:EQU  158260989.0
# 2019-09  4SI:XJSE:EQU  158260989.0
# 2019-08  4SI:XJSE:EQU  142434890.0
# ...               ...          ...
# 2009-05  ZED:XJSE:EQU  880279665.0
# 2009-04  ZED:XJSE:EQU  904687478.0
# 2009-03  ZED:XJSE:EQU  855785452.0
# 2009-02  ZED:XJSE:EQU  892461971.0
# 2009-01  ZED:XJSE:EQU  947476750.0
#
# [42504 rows x 2 columns]

# %%
df_MR = pd.read_excel("J203T Price.xlsx", usecols=[0,1], index_col=0)
df_MR
# Out:
#                J203T
# Dates
# 2000-01-04   694.664
# 2000-01-05   687.378
# 2000-01-06   688.400
# 2000-01-07   705.859
# 2000-01-10   729.218
# ...              ...
# 2020-02-24  8332.211
# 2020-02-25  8321.271
# 2020-02-26  8357.358
# 2020-02-27  8114.083
# 2020-02-28  7748.701
#
# [5258 rows x 1 columns]

# %%
df_RF = pd.read_excel("91days T-Bill rate.xlsx", index_col=0)
df_RF
# Out:
#             Value
# Date
# 2000-01-05  10.71
# 2000-01-06  10.71
# 2000-01-07  10.56
# 2000-01-10  10.56
# 2000-01-11  10.56
# ...           ...
# 2019-12-25   7.19
# 2019-12-26   7.19
# 2019-12-27   7.16
# 2019-12-30   7.16
# 2019-12-31   7.16
#
# [5215 rows x 1 columns]

# %% [markdown]
# ## Sorting Data

# %% [markdown]
# Reform price data frame

# %%
tmp = pd.DataFrame()
labels = []
n = int((2019-2009+1)*12)

for i in range(int(len(df_price)/n)): 
    price = pd.DataFrame(df_price.iloc[(n*(i-1)):(n*i),1])
    name = df_price.iloc[range(1,len(df_price),n)[i],0]
    tmp = pd.concat([tmp,price], axis=1)
    labels.append(name)
    tmp.columns = [labels]

# %%
df_price = tmp
# reorder the date of price data
df_price = df_price.sort_index(ascending=True)
df_price.columns = df_price.columns.get_level_values(0).values
df_price
# Out:
#          4SI:XJSE:EQU  ABG:XJSE:EQU  APF:XJSE:EQU  ACS:XJSE:EQU  AIP:XJSE:EQU  \
# Date
# 2009-01           NaN           NaN        9300.0           NaN           NaN
# 2009-02           NaN           NaN        8900.0           NaN           NaN
# 2009-03           NaN           NaN        9620.0           NaN           NaN
# 2009-04           NaN           NaN        9845.0           NaN           NaN
# 2009-05           NaN           NaN       10155.0           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 2019-08           NaN          18.0       15369.0         295.0         725.0
# 2019-09           NaN          20.0       15287.0         174.0         725.0
# 2019-10           NaN          20.0       15488.0         198.0         600.0
# 2019-11           NaN          20.0       14726.0         165.0         715.0
# 2019-12           NaN          32.0       14930.0         175.0         650.0
#
#          ADR:XJSE:EQU  AVL:XJSE:EQU  ADH:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  \
# Date
# 2009-01        4000.0        2290.0           NaN         370.0        5099.0
# 2009-02        3826.0        2050.0           NaN         350.0        4399.0
# 2009-03        3600.0        1700.0           NaN         371.0        4400.0
# 2009-04        4200.0        2100.0           NaN         400.0        4875.0
# 2009-05        4200.0        2300.0           NaN         415.0        4600.0
# ...               ...           ...           ...           ...           ...
# 2019-08        5775.0        2000.0          45.0        1109.0        9099.0
# 2019-09        5675.0        2055.0          38.0        1250.0        9596.0
# 2019-10        5624.0        1370.0          42.0        1125.0        9765.0
# 2019-11        5501.0        1105.0          39.0        1070.0       10528.0
# 2019-12        5378.0        1300.0          40.0        1080.0       10700.0
#
#          ...  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  WEA:XJSE:EQU  \
# Date     ...
# 2009-01  ...           NaN         905.0        1750.0         116.0
# 2009-02  ...           NaN         825.0         850.0         108.0
# 2009-03  ...           NaN         919.0        1500.0         120.0
# 2009-04  ...           NaN         930.0         750.0         134.0
# 2009-05  ...        5200.0         960.0         600.0         170.0
# ...      ...           ...           ...           ...           ...
# 2019-08  ...       11529.0        1872.0         255.0          40.0
# 2019-09  ...       11964.0        1900.0         255.0          52.0
# 2019-10  ...       13185.0        1934.0         250.0          55.0
# 2019-11  ...       12112.0        1970.0         249.0          54.0
# 2019-12  ...       11530.0        1940.0         240.0          51.0
#
#          WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  \
# Date
# 2009-01          64.0        9718.0        1345.0             32.0
# 2009-02          40.0        8500.0        1190.0             25.0
# 2009-03          54.0        8509.0        1140.0             18.0
# 2009-04          70.0       10001.0        1200.0             18.0
# 2009-05          55.0       10355.0        1250.0             22.0
# ...               ...           ...           ...              ...
# 2019-08           3.0       10018.0        5518.0            140.0
# 2019-09           3.0       14290.0        5508.0            160.0
# 2019-10           3.0       14118.0        5749.0            160.0
# 2019-11           3.0       14054.0        5218.0            159.0
# 2019-12           3.0       13811.0        4860.0            150.0
#
#          YRK:XJSE:EQU  ZED:XJSE:EQU
# Date
# 2009-01           NaN        1600.0
# 2009-02           NaN        1150.0
# 2009-03           NaN         540.0
# 2009-04           NaN         540.0
# 2009-05           NaN         460.0
# ...               ...           ...
# 2019-08        1800.0         170.0
# 2019-09        1840.0         160.0
# 2019-10        1865.0         160.0
# 2019-11        2000.0         160.0
# 2019-12        1740.0         149.0
#
# [132 rows x 322 columns]

# %% [markdown]
# Reform size data frame

# %%
tmp = pd.DataFrame()

for i in range(int(len(df_size)/n)): 
    size = pd.DataFrame(df_size.iloc[(n*(i-1)):(n*i),1])
    tmp = pd.concat([tmp,size], axis=1)
tmp.columns = flatten([labels])

# %%
df_size = tmp
# reorder the date of size data
df_size = df_size.sort_index(ascending=True)
df_size
# Out:
#          4SI:XJSE:EQU  ABG:XJSE:EQU  APF:XJSE:EQU  ACS:XJSE:EQU  AIP:XJSE:EQU  \
# Date
# 2009-01           NaN           NaN  6.326588e+10           NaN           NaN
# 2009-02           NaN           NaN  6.054477e+10           NaN           NaN
# 2009-03           NaN           NaN  6.545181e+10           NaN           NaN
# 2009-04           NaN           NaN  6.698264e+10           NaN           NaN
# 2009-05           NaN           NaN  6.909180e+10           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 2019-08           NaN   142434890.0  1.302908e+11  2.945648e+09  2.863460e+09
# 2019-09           NaN   158260989.0  1.295956e+11  1.737433e+09  2.863460e+09
# 2019-10           NaN   158260989.0  1.312996e+11  1.977079e+09  2.369760e+09
# 2019-11           NaN   158260989.0  1.248398e+11  1.647566e+09  2.823964e+09
# 2019-12           NaN   253217582.0  1.265692e+11  1.747418e+09  2.567240e+09
#
#          ADR:XJSE:EQU  AVL:XJSE:EQU  ADH:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  \
# Date
# 2009-01  6.916287e+09  1.238633e+09           NaN  1.456560e+09  6.060008e+09
# 2009-02  6.615428e+09  1.111497e+09           NaN  1.377827e+09  5.228079e+09
# 2009-03  6.224658e+09  9.217295e+08           NaN  1.460497e+09  5.229267e+09
# 2009-04  7.262101e+09  1.138607e+09           NaN  1.574660e+09  5.793791e+09
# 2009-05  7.262101e+09  1.247046e+09           NaN  1.633709e+09  5.466961e+09
# ...               ...           ...           ...           ...           ...
# 2019-08  1.015007e+10  2.199094e+09   129594794.0  6.061937e+09  1.108523e+10
# 2019-09  9.974315e+09  2.259569e+09   109435604.0  6.832661e+09  1.169072e+10
# 2019-10  9.884678e+09  1.506379e+09   120955141.0  6.149395e+09  1.189661e+10
# 2019-11  9.668495e+09  1.214999e+09   112315488.0  5.848758e+09  1.282617e+10
# 2019-12  9.452312e+09  1.429411e+09   115195373.0  5.926683e+09  1.303571e+10
#
#          ...  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  WEA:XJSE:EQU  \
# Date     ...
# 2009-01  ...           NaN  2.674735e+09   431987500.0   679168221.0
# 2009-02  ...           NaN  2.438295e+09   209822500.0   632329033.0
# 2009-03  ...           NaN  2.716113e+09   370275000.0   702587815.0
# 2009-04  ...           NaN  2.748623e+09   185137500.0   784556393.0
# 2009-05  ...  7.737361e+10  2.837288e+09   148110000.0   995332738.0
# ...      ...           ...           ...           ...           ...
# 2019-08  ...  2.116569e+11  1.790056e+10   410947583.0   651130823.0
# 2019-09  ...  2.196429e+11  1.816831e+10   410947583.0   846470070.0
# 2019-10  ...  2.420588e+11  1.849342e+10   402889787.0   895304881.0
# 2019-11  ...  2.223600e+11  1.883766e+10   401278228.0   879026611.0
# 2019-12  ...  2.116752e+11  1.855080e+10   386774196.0   830191799.0
#
#          WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  \
# Date
# 2009-01   117095434.0  6.413880e+09  1.074192e+10       76800000.0
# 2009-02    73184646.0  5.610000e+09  9.504005e+09       60000000.0
# 2009-03    98799273.0  5.615940e+09  9.112693e+09       43200000.0
# 2009-04   128073131.0  6.600660e+09  9.592308e+09       43200000.0
# 2009-05   100903889.0  6.834300e+09  9.991988e+09       52800000.0
# ...               ...           ...           ...              ...
# 2019-08     8291796.0  5.999832e+09  5.785436e+10      341223880.0
# 2019-09     8291796.0  8.558354e+09  5.774957e+10      389970148.0
# 2019-10     8291796.0  8.455343e+09  6.027737e+10      389970148.0
# 2019-11     8291796.0  8.417013e+09  5.471213e+10      387532835.0
# 2019-12     8291796.0  8.271479e+09  5.095873e+10      365597014.0
#
#          YRK:XJSE:EQU  ZED:XJSE:EQU
# Date
# 2009-01           NaN  1.253921e+09
# 2009-02           NaN  9.012558e+08
# 2009-03           NaN  4.231984e+08
# 2009-04           NaN  4.231984e+08
# 2009-05           NaN  3.605023e+08
# ...               ...           ...
# 2019-08  9.524873e+08  5.631090e+08
# 2019-09  9.736537e+08  5.299850e+08
# 2019-10  9.868827e+08  5.299850e+08
# 2019-11  1.058319e+09  5.299850e+08
# 2019-12  9.207377e+08  4.935485e+08
#
# [132 rows x 322 columns]

# %% [markdown]
# Calculate stock returns

# %%
# np.log(1 + df_price.pct_change()) #or below
df_SR = np.log(df_price/df_price.shift(1)) # formula = ln(Pt/Pt-1)
df_SR = df_SR.iloc[1:,:]
df_SR.replace([np.inf, -np.inf], np.nan, inplace=True) # replace the inf number to NA as ln(0) will return inf
# np.isinf(df_SR).sum().sum() # test whether infs are replaced 
df_SR
# Out:
#          4SI:XJSE:EQU  ABG:XJSE:EQU  APF:XJSE:EQU  ACS:XJSE:EQU  AIP:XJSE:EQU  \
# Date
# 2009-02           NaN           NaN     -0.043963           NaN           NaN
# 2009-03           NaN           NaN      0.077793           NaN           NaN
# 2009-04           NaN           NaN      0.023119           NaN           NaN
# 2009-05           NaN           NaN      0.031002           NaN           NaN
# 2009-06           NaN           NaN      0.079929           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 2019-08           NaN      0.000000     -0.038234      0.000000      0.189242
# 2019-09           NaN      0.105361     -0.005350     -0.527920      0.000000
# 2019-10           NaN      0.000000      0.013063      0.129212     -0.189242
# 2019-11           NaN      0.000000     -0.050451     -0.182322      0.175353
# 2019-12           NaN      0.470004      0.013758      0.058841     -0.095310
#
#          ADR:XJSE:EQU  AVL:XJSE:EQU  ADH:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  \
# Date
# 2009-02     -0.044474     -0.110712           NaN     -0.055570     -0.147667
# 2009-03     -0.060886     -0.187212           NaN      0.058269      0.000227
# 2009-04      0.154151      0.211309           NaN      0.075262      0.102516
# 2009-05      0.000000      0.090972           NaN      0.036814     -0.058064
# 2009-06      0.015123      0.042560           NaN      0.035507      0.010811
# ...               ...           ...           ...           ...           ...
# 2019-08      0.006079     -0.159138     -0.200671     -0.131613     -0.021850
# 2019-09     -0.017468      0.027129     -0.169076      0.119685      0.053182
# 2019-10     -0.009027     -0.405465      0.100083     -0.105361      0.017458
# 2019-11     -0.022113     -0.214965     -0.074108     -0.050124      0.075234
# 2019-12     -0.022613      0.162519      0.025318      0.009302      0.016205
#
#          ...  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  WEA:XJSE:EQU  \
# Date     ...
# 2009-02  ...           NaN     -0.092552     -0.722135     -0.071459
# 2009-03  ...           NaN      0.107903      0.567984      0.105361
# 2009-04  ...           NaN      0.011898     -0.693147      0.110348
# 2009-05  ...           NaN      0.031749     -0.223144      0.237959
# 2009-06  ...      0.095310     -0.121697     -0.182322      0.344840
# ...      ...           ...           ...           ...           ...
# 2019-08  ...     -0.020348     -0.008511      0.060625      0.025318
# 2019-09  ...      0.037037      0.014847      0.000000      0.262364
# 2019-10  ...      0.097178      0.017737     -0.019803      0.056089
# 2019-11  ...     -0.084883      0.018443     -0.004008     -0.018349
# 2019-12  ...     -0.049244     -0.015346     -0.036814     -0.057158
#
#          WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  \
# Date
# 2009-02     -0.470004     -0.133914     -0.122441        -0.246860
# 2009-03      0.300105      0.001058     -0.042925        -0.328504
# 2009-04      0.259511      0.161561      0.051293         0.000000
# 2009-05     -0.241162      0.034784      0.040822         0.200671
# 2009-06     -0.178692      0.025270      0.035367         0.127833
# ...               ...           ...           ...              ...
# 2019-08      0.000000     -0.140656      0.003267        -0.035091
# 2019-09      0.000000      0.355177     -0.001814         0.133531
# 2019-10      0.000000     -0.012109      0.042824         0.000000
# 2019-11      0.000000     -0.004544     -0.096912        -0.006270
# 2019-12      0.000000     -0.017442     -0.071076        -0.058269
#
#          YRK:XJSE:EQU  ZED:XJSE:EQU
# Date
# 2009-02           NaN     -0.330242
# 2009-03           NaN     -0.755948
# 2009-04           NaN      0.000000
# 2009-05           NaN     -0.160343
# 2009-06           NaN     -0.044452
# ...               ...           ...
# 2019-08      0.045462      0.000000
# 2019-09      0.021979     -0.060625
# 2019-10      0.013495      0.000000
# 2019-11      0.069886      0.000000
# 2019-12     -0.139262     -0.071228
#
# [131 rows x 322 columns]

# %% [markdown]
# Calculate risk-free and market returns

# %%
df_RF = (1+df_RF['Value'].astype(np.float64)/100)**(1/365)-1
df_RF.index = pd.to_datetime(df_RF.index)
df_RF = pd.DataFrame(df_RF.resample('M').sum())
df_RF.index = df_RF.index.to_series().dt.to_period('M')
df_RF = df_RF.loc[df_SR.index,:]
df_RF
# Out:
#             Value
# Date
# 2009-02  0.004854
# 2009-03  0.004984
# 2009-04  0.004798
# 2009-05  0.004276
# 2009-06  0.004203
# ...           ...
# 2019-08  0.004076
# 2019-09  0.003813
# 2019-10  0.004153
# 2019-11  0.003893
# 2019-12  0.004153
#
# [131 rows x 1 columns]

# %%
tmp = np.log(df_MR/df_MR.shift(1))
df_MR = tmp.iloc[1:,:]
df_MR.index = pd.to_datetime(df_MR.index)
df_MR = pd.DataFrame(df_MR.resample('M',convention='end').sum())
df_MR.index = df_MR.index.to_series().dt.to_period('M')
df_MR = df_MR.loc[df_SR.index,:]
df_MR
# Out:
#             J203T
# Date
# 2009-02 -0.103955
# 2009-03  0.104531
# 2009-04  0.015669
# 2009-05  0.098319
# 2009-06 -0.031028
# ...           ...
# 2019-08 -0.024655
# 2019-09  0.001913
# 2019-10  0.030952
# 2019-11 -0.018123
# 2019-12  0.032479
#
# [131 rows x 1 columns]

# %% [markdown]
# Calculate stock excess returns

# %%
df_Ex_SR = df_SR.apply(lambda x: x-df_RF.iloc[:,0], axis=0)
df_Ex_SR
# Out:
#          4SI:XJSE:EQU  ABG:XJSE:EQU  APF:XJSE:EQU  ACS:XJSE:EQU  AIP:XJSE:EQU  \
# Date
# 2009-02           NaN           NaN     -0.048818           NaN           NaN
# 2009-03           NaN           NaN      0.072809           NaN           NaN
# 2009-04           NaN           NaN      0.018321           NaN           NaN
# 2009-05           NaN           NaN      0.026726           NaN           NaN
# 2009-06           NaN           NaN      0.075726           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 2019-08           NaN     -0.004076     -0.042310     -0.004076      0.185166
# 2019-09           NaN      0.101547     -0.009163     -0.531733     -0.003813
# 2019-10           NaN     -0.004153      0.008910      0.125059     -0.193395
# 2019-11           NaN     -0.003893     -0.054344     -0.186215      0.171460
# 2019-12           NaN      0.465850      0.009605      0.054687     -0.099463
#
#          ADR:XJSE:EQU  AVL:XJSE:EQU  ADH:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  \
# Date
# 2009-02     -0.049329     -0.115567           NaN     -0.060424     -0.152522
# 2009-03     -0.065870     -0.192196           NaN      0.053285     -0.004757
# 2009-04      0.149353      0.206511           NaN      0.070464      0.097717
# 2009-05     -0.004276      0.086696           NaN      0.032538     -0.062340
# 2009-06      0.010920      0.038356           NaN      0.031303      0.006608
# ...               ...           ...           ...           ...           ...
# 2019-08      0.002003     -0.163214     -0.204746     -0.135689     -0.025925
# 2019-09     -0.021281      0.023315     -0.172890      0.115872      0.049368
# 2019-10     -0.013180     -0.409618      0.095931     -0.109513      0.013305
# 2019-11     -0.026007     -0.218859     -0.078001     -0.054018      0.071341
# 2019-12     -0.026766      0.158366      0.021165      0.005149      0.012052
#
#          ...  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  WEA:XJSE:EQU  \
# Date     ...
# 2009-02  ...           NaN     -0.097406     -0.726989     -0.076313
# 2009-03  ...           NaN      0.102918      0.563000      0.100376
# 2009-04  ...           NaN      0.007100     -0.697945      0.105550
# 2009-05  ...           NaN      0.027473     -0.227420      0.233683
# 2009-06  ...      0.091107     -0.125900     -0.186525      0.340637
# ...      ...           ...           ...           ...           ...
# 2019-08  ...     -0.024424     -0.012586      0.056549      0.021242
# 2019-09  ...      0.033223      0.011033     -0.003813      0.258551
# 2019-10  ...      0.093025      0.013584     -0.023955      0.051937
# 2019-11  ...     -0.088776      0.014550     -0.007901     -0.022242
# 2019-12  ...     -0.053398     -0.019499     -0.040967     -0.061312
#
#          WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  \
# Date
# 2009-02     -0.474858     -0.138768     -0.127295        -0.251715
# 2009-03      0.295120     -0.003926     -0.047909        -0.333488
# 2009-04      0.254713      0.156763      0.046495        -0.004798
# 2009-05     -0.245438      0.030508      0.036546         0.196395
# 2009-06     -0.182895      0.021066      0.031164         0.123630
# ...               ...           ...           ...              ...
# 2019-08     -0.004076     -0.144731     -0.000808        -0.039167
# 2019-09     -0.003813      0.351363     -0.005627         0.129718
# 2019-10     -0.004153     -0.016262      0.038672        -0.004153
# 2019-11     -0.003893     -0.008437     -0.100805        -0.010163
# 2019-12     -0.004153     -0.021595     -0.075229        -0.062422
#
#          YRK:XJSE:EQU  ZED:XJSE:EQU
# Date
# 2009-02           NaN     -0.335096
# 2009-03           NaN     -0.760932
# 2009-04           NaN     -0.004798
# 2009-05           NaN     -0.164619
# 2009-06           NaN     -0.048655
# ...               ...           ...
# 2019-08      0.041387     -0.004076
# 2019-09      0.018166     -0.064438
# 2019-10      0.009343     -0.004153
# 2019-11      0.065993     -0.003893
# 2019-12     -0.143415     -0.075381
#
# [131 rows x 322 columns]

# %% [markdown]
# ## CAPM Regression (Time-Varying Betas)

# %% [markdown]
# We use a rolling window of 36 month to estimate market betas, and these betas are updated monthly.

# %%
holding = 1 # Define the update frequency
rollingW = 36 # Define the length of lookback estimation window
lens = len(df_Ex_SR)
periods = int((lens - rollingW) / holding) # Calculate the holding periods
print(periods,rollingW)
# Out:
# 95 36

# %%
all_betas = []

for i in tqdm(range(periods)):

    df_MR_tmp = df_MR.iloc[i*holding:i*holding+rollingW,:]
    df_Ex_SR_tmp = df_Ex_SR.iloc[i*holding:i*holding+rollingW,:]

    betas = []
    labels = []
    for j in df_Ex_SR.columns:
        # drop the NA returns and only keep the date that have valid returns
        df_index = df_Ex_SR_tmp.loc[:,j].dropna().index
        if len(df_index) >= 2: # We can only draw a line based on two points or above
            ols = sm.OLS(df_Ex_SR_tmp.loc[df_index,j].values.astype(np.float64), 
            sm.add_constant(df_MR_tmp.loc[df_index,:].values.astype(np.float64)))
            res = ols.fit()
            b = res.params[1] # Only betas
            betas.append(b)
            labels.append(j)

    df_betas = pd.DataFrame(np.array(betas)).rename(columns={0:'Beta'})
    df_betas.index = labels
    all_betas.append(df_betas.T)
# Out:
# 100%|██████████| 95/95 [00:12<00:00,  7.60it/s]

# %%
all_betas[0].columns
# Out:
# Index(['APF:XJSE:EQU', 'ADR:XJSE:EQU', 'AVL:XJSE:EQU', 'AFE:XJSE:EQU',
#        'ANI:XJSE:EQU', 'AON:XJSE:EQU', 'AOVP:XJSE:EQU', 'ADW:XJSE:EQU',
#        'AEE:XJSE:EQU', 'AME:XJSE:EQU',
#        ...
#        'UPL:XJSE:EQU', 'VKE:XJSE:EQU', 'VUN:XJSE:EQU', 'WEZ:XJSE:EQU',
#        'WEA:XJSE:EQU', 'WBO:XJSE:EQU', 'WHL:XJSE:EQU', 'WKF:XJSE:EQU',
#        'YYLBEE:XJSE:EQU', 'ZED:XJSE:EQU'],
#       dtype='object', length=211)

# %%
k = np.random.randint(0,periods-1)
print(k)
all_betas[k]
# Out:
# 57
#       APF:XJSE:EQU  ACS:XJSE:EQU  AIP:XJSE:EQU  ADR:XJSE:EQU  AVL:XJSE:EQU  \
# Beta      1.175492      0.004858     -0.679674       0.79659      0.329868
#
#       ADH:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  AON:XJSE:EQU  AOVP:XJSE:EQU  \
# Beta      -0.09883     -0.230867      0.936199      1.166613        0.07057
#
#       ...  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  WEA:XJSE:EQU  \
# Beta  ...      1.098279      0.868705      0.489083      1.207867
#
#       WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  YRK:XJSE:EQU  \
# Beta      3.080327      0.132555      1.159589        -0.318897      4.736338
#
#       ZED:XJSE:EQU
# Beta      0.967447
#
# [1 rows x 263 columns]

# %% [markdown]
# Ranking betas

# %%
mean_betas = []
rank_betas = []

for i in tqdm(range(periods)):
    rank_betas.append(all_betas[i].rank(na_option="keep", axis=1))
#     number_of_portfolios = 5
#     N = len(rank_betas)
#     quantile = int(N/number_of_portfolios)
#     return [Low_Beta=names(rank_betas)[rank_betas][1:quantile],
#             P1=names(rank_betas)[rank_betas][(quantile+1):(2*quantile)],
#             P2=names(rank_betas)[rank_betas][(2*quantile+1):(3*quantile)],
#             P3=names(rank_betas)[rank_betas][(3*quantile+1):(N-quantile)],
#             High_Beta=names(rank_betas)[rank_betas][(N-quantile+1):N])]
# Out:
# 100%|██████████| 94/94 [00:00<00:00, 5844.77it/s]

# %%
rank_betas[0]
# Out:
#       APF:XJSE:EQU  ADR:XJSE:EQU  AVL:XJSE:EQU  AFE:XJSE:EQU  ANI:XJSE:EQU  \
# Beta         159.0          82.0          32.0         103.0         126.0
#
#       AON:XJSE:EQU  AOVP:XJSE:EQU  ADW:XJSE:EQU  AEE:XJSE:EQU  AME:XJSE:EQU  \
# Beta          16.0            6.0          10.0         191.0          59.0
#
#       ...  UPL:XJSE:EQU  VKE:XJSE:EQU  VUN:XJSE:EQU  WEZ:XJSE:EQU  \
# Beta  ...         179.0          97.0         129.0         206.0
#
#       WEA:XJSE:EQU  WBO:XJSE:EQU  WHL:XJSE:EQU  WKF:XJSE:EQU  YYLBEE:XJSE:EQU  \
# Beta          77.0         200.0         145.0         165.0             25.0
#
#       ZED:XJSE:EQU
# Beta          12.0
#
# [1 rows x 211 columns]

# %%
number_of_portfolios = 5
N = len(rank_betas[0])
quantile = int(N/number_of_portfolios)

# %%
rank_betas[0].values.astype(np.int_)-1
# Out:
# array([[158,  81,  31, 102, 125,  15,   5,   9, 190,  58,  67, 185,  87,
#         175,  16,   1, 151,  73, 187, 208, 126, 112, 124, 120, 133,  93,
#         134, 103, 186, 108, 118, 168, 184, 165, 106,  89,  95,  77, 111,
#          69,  64,   3,  40,  80,  43, 119, 122, 129, 170,  61, 116, 138,
#          53,  88, 130,  13, 137,  47,  17, 173, 189,  54, 142, 135, 100,
#          23,  45, 150,  27, 159,  62,  49,  86, 196,   8, 177, 154, 198,
#           6, 210, 169,  59,   4, 193, 110,  71, 157,  98,  41,  65, 156,
#           7, 153,  79,  50,  21, 201, 188, 203, 202, 101, 127,  74, 114,
#          46, 162,  99,  84,   0, 155,   2, 160,  48,  34,  14,  29, 139,
#         192, 204,  52,  33, 183, 148, 207,  66, 146, 171, 149,  63,  78,
#         191, 174,  55, 121,  18, 181, 117, 209, 176,  28,  42,  37, 147,
#          26,  75, 131, 104,  25, 107,  32, 194,  51, 152, 166,  94,  35,
#          97,  72, 115, 141,  44,  39, 143,  20,  22, 161, 136,  70,  56,
#         123, 172,  38, 113, 206,  83, 180,  10,  92,  90,  57, 195, 140,
#         163,  60, 182, 145, 200,  36,  12,  30, 179,  91, 132,  19,  82,
#          85, 109,  68, 197, 167, 105, 178,  96, 128, 205,  76, 199, 144,
#         164,  24,  11]])

# %%
ranks = np.array(np.array(rank_betas[0].columns)[rank_betas[0].values.astype(np.int_)-1,None]).reshape(len(rank_betas[0].columns),1)

# %%
ranks
# Out:
# array([['REM:XJSE:EQU'],
#        ['FFB:XJSE:EQU'],
#        ['BEL:XJSE:EQU'],
#        ['ITE:XJSE:EQU'],
#        ['MTN:XJSE:EQU'],
#        ['AFH:XJSE:EQU'],
#        ['AON:XJSE:EQU'],
#        ['AME:XJSE:EQU'],
#        ['SPP:XJSE:EQU'],
#        ['COH:XJSE:EQU'],
#        ['EEL:XJSE:EQU'],
#        ['SPG:XJSE:EQU'],
#        ['HMN:XJSE:EQU'],
#        ['SCD:XJSE:EQU'],
#        ['AVV:XJSE:EQU'],
#        ['ADR:XJSE:EQU'],
#        ['QFH:XJSE:EQU'],
#        ['EUZ:XJSE:EQU'],
#        ['TKG:XJSE:EQU'],
#        ['WKF:XJSE:EQU'],
#        ['MTNZF:XJSE:EQU'],
#        ['LTE:XJSE:EQU'],
#        ['MRP:XJSE:EQU'],
#        ['MIX:XJSE:EQU'],
#        ['NFP:XJSE:EQU'],
#        ['HYP:XJSE:EQU'],
#        ['NY1:XJSE:EQU'],
#        ['JSC:XJSE:EQU'],
#        ['SYG:XJSE:EQU'],
#        ['KP2:XJSE:EQU'],
#        ['MTA:XJSE:EQU'],
#        ['SBP:XJSE:EQU'],
#        ['SSS:XJSE:EQU'],
#        ['RBP:XJSE:EQU'],
#        ['KAL:XJSE:EQU'],
#        ['HDC:XJSE:EQU'],
#        ['IMP:XJSE:EQU'],
#        ['FSE:XJSE:EQU'],
#        ['L2D:XJSE:EQU'],
#        ['EMI:XJSE:EQU'],
#        ['EMH:XJSE:EQU'],
#        ['AFE:XJSE:EQU'],
#        ['BUC:XJSE:EQU'],
#        ['FFA:XJSE:EQU'],
#        ['CRP:XJSE:EQU'],
#        ['MFL:XJSE:EQU'],
#        ['MNP:XJSE:EQU'],
#        ['NPN:XJSE:EQU'],
#        ['SNT:XJSE:EQU'],
#        ['DIB:XJSE:EQU'],
#        ['MDI:XJSE:EQU'],
#        ['OAS:XJSE:EQU'],
#        ['CMH:XJSE:EQU'],
#        ['HET:XJSE:EQU'],
#        ['NED:XJSE:EQU'],
#        ['ACT:XJSE:EQU'],
#        ['OAO:XJSE:EQU'],
#        ['CAT:XJSE:EQU'],
#        ['AMS:XJSE:EQU'],
#        ['SAPCB:XJSE:IBI'],
#        ['THA:XJSE:EQU'],
#        ['CFRO:XJSE:DER'],
#        ['OLG:XJSE:EQU'],
#        ['NVS:XJSE:EQU'],
#        ['IVT:XJSE:EQU'],
#        ['ASC:XJSE:EQU'],
#        ['CSB:XJSE:EQU'],
#        ['PPR:XJSE:EQU'],
#        ['AYO:XJSE:EQU'],
#        ['REN:XJSE:EQU'],
#        ['DCP:XJSE:EQU'],
#        ['CLH:XJSE:EQU'],
#        ['GSH:XJSE:EQU'],
#        ['TRE:XJSE:EQU'],
#        ['AEE:XJSE:EQU'],
#        ['SHP:XJSE:EQU'],
#        ['RAV:XJSE:EQU'],
#        ['TRU:XJSE:EQU'],
#        ['AOVP:XJSE:EQU'],
#        ['ZED:XJSE:EQU'],
#        ['SLM:XJSE:EQU'],
#        ['DTC:XJSE:EQU'],
#        ['ANI:XJSE:EQU'],
#        ['TDH:XJSE:EQU'],
#        ['LEW:XJSE:EQU'],
#        ['EOH:XJSE:EQU'],
#        ['RNI:XJSE:EQU'],
#        ['INP:XJSE:EQU'],
#        ['BYI:XJSE:EQU'],
#        ['EMN:XJSE:EQU'],
#        ['RDF:XJSE:EQU'],
#        ['ADW:XJSE:EQU'],
#        ['RBX:XJSE:EQU'],
#        ['FSR:XJSE:EQU'],
#        ['CLS:XJSE:EQU'],
#        ['ACL:XJSE:EQU'],
#        ['UPL:XJSE:EQU'],
#        ['TXT:XJSE:EQU'],
#        ['VUN:XJSE:EQU'],
#        ['VKE:XJSE:EQU'],
#        ['IAP:XJSE:EQU'],
#        ['MST:XJSE:EQU'],
#        ['EXP:XJSE:EQU'],
#        ['MSP:XJSE:EQU'],
#        ['CVW:XJSE:EQU'],
#        ['RTN:XJSE:EQU'],
#        ['IPF:XJSE:EQU'],
#        ['GPL:XJSE:EQU'],
#        ['APF:XJSE:EQU'],
#        ['REB:XJSE:EQU'],
#        ['AVL:XJSE:EQU'],
#        ['RSG:XJSE:EQU'],
#        ['CHP:XJSE:EQU'],
#        ['BCF:XJSE:EQU'],
#        ['AHL:XJSE:EQU'],
#        ['BAU:XJSE:EQU'],
#        ['OCE:XJSE:EQU'],
#        ['TON:XJSE:EQU'],
#        ['WEZ:XJSE:EQU'],
#        ['CGN:XJSE:EQU'],
#        ['BLU:XJSE:EQU'],
#        ['SNH:XJSE:EQU'],
#        ['KST:XJSE:EQU'],
#        ['WHL:XJSE:EQU'],
#        ['EPS:XJSE:EQU'],
#        ['PFB:XJSE:EQU'],
#        ['SNV:XJSE:EQU'],
#        ['PPE:XJSE:EQU'],
#        ['DGH:XJSE:EQU'],
#        ['FSEO1:XJSE:DER'],
#        ['TGA:XJSE:EQU'],
#        ['SOL:XJSE:EQU'],
#        ['CML:XJSE:EQU'],
#        ['MTM:XJSE:EQU'],
#        ['AGL:XJSE:EQU'],
#        ['SDO:XJSE:EQU'],
#        ['MEI:XJSE:EQU'],
#        ['YYLBEE:XJSE:EQU'],
#        ['SEP:XJSE:EQU'],
#        ['BSR:XJSE:EQU'],
#        ['CGR:XJSE:EQU'],
#        ['BRT:XJSE:EQU'],
#        ['PRX:XJSE:EQU'],
#        ['AVI:XJSE:EQU'],
#        ['FTA:XJSE:EQU'],
#        ['NRP:XJSE:EQU'],
#        ['JSE:XJSE:EQU'],
#        ['ATT:XJSE:EQU'],
#        ['KRO:XJSE:EQU'],
#        ['BHG:XJSE:EQU'],
#        ['TCP:XJSE:EQU'],
#        ['CLI:XJSE:EQU'],
#        ['RNG:XJSE:EQU'],
#        ['SAC:XJSE:EQU'],
#        ['ILE:XJSE:EQU'],
#        ['BIHLEB:XJSE:IBI'],
#        ['INL:XJSE:EQU'],
#        ['EPE:XJSE:EQU'],
#        ['MSM:XJSE:EQU'],
#        ['OMU:XJSE:EQU'],
#        ['CPI:XJSE:EQU'],
#        ['BTI:XJSE:EQU'],
#        ['ORN:XJSE:EQU'],
#        ['ANH:XJSE:EQU'],
#        ['ACZ:XJSE:EQU'],
#        ['RLO:XJSE:EQU'],
#        ['NUT:XJSE:EQU'],
#        ['ENX:XJSE:EQU'],
#        ['CKS:XJSE:EQU'],
#        ['MKR:XJSE:EQU'],
#        ['SAP:XJSE:EQU'],
#        ['BRN:XJSE:EQU'],
#        ['L4L:XJSE:EQU'],
#        ['WBO:XJSE:EQU'],
#        ['GLN:XJSE:EQU'],
#        ['S32:XJSE:EQU'],
#        ['AIL:XJSE:EQU'],
#        ['HUL:XJSE:EQU'],
#        ['HUG:XJSE:EQU'],
#        ['CSG:XJSE:EQU'],
#        ['TRL:XJSE:EQU'],
#        ['OCT:XJSE:EQU'],
#        ['RTO:XJSE:EQU'],
#        ['DLT:XJSE:EQU'],
#        ['SSK:XJSE:EQU'],
#        ['PPC:XJSE:EQU'],
#        ['TGO:XJSE:EQU'],
#        ['BIK:XJSE:EQU'],
#        ['ATI:XJSE:EQU'],
#        ['SOLBE1:XJSE:EQU'],
#        ['SRE:XJSE:EQU'],
#        ['HLM:XJSE:EQU'],
#        ['NTC:XJSE:EQU'],
#        ['ANG:XJSE:EQU'],
#        ['FTH:XJSE:EQU'],
#        ['GND:XJSE:EQU'],
#        ['LAB:XJSE:EQU'],
#        ['ELI:XJSE:EQU'],
#        ['TTO:XJSE:EQU'],
#        ['SZK:XJSE:EQU'],
#        ['JBL:XJSE:EQU'],
#        ['SSW:XJSE:EQU'],
#        ['ILU:XJSE:EQU'],
#        ['NPK:XJSE:EQU'],
#        ['WEA:XJSE:EQU'],
#        ['FGL:XJSE:EQU'],
#        ['TSG:XJSE:EQU'],
#        ['PBG:XJSE:EQU'],
#        ['RFG:XJSE:EQU'],
#        ['ARA:XJSE:EQU'],
#        ['AFT:XJSE:EQU']], dtype=object)

# %%
x = {"Low_Beta": ranks[1:quantile], "P1": ranks[(quantile+1):(2*quantile)],
"P2": ranks[(2*quantile+1):(3*quantile)], "P3": ranks[(3*quantile+1):(4*quantile)],
"High_Beta": ranks[(N-quantile+1):N]}
